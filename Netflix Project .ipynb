# %% [markdown]
# IMPORTING THE DATA

# %%
# importing the dataset
import pandas as pd 
data = pd.read_csv(r"C:\Users\ADMIN\Desktop\Business Analyst\Projects\PYTHON\8. Netflix Dataset.csv")

# %% [markdown]
# TO VIEW THE DATA - IT WILL INCLUDE THE FIRST AND LAST 5 RECORDS WITH ALL COLUMNS

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# TO VIEW THE FIRST 5 RECORDS -HEAD()

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %% [markdown]
# TO VIEW THE BOTTOM 5 RECORDS -TAIL()

# %%
data.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %% [markdown]
# TO VIEW THE FIRST RECORDS AS PER CHOICE -HEAD(NO)

# %%
data.head(4)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# ...

# %% [markdown]
# TO VIEW THE BOTTOM 5 RECORDS AS PER CHOICE -TAIL(NO)

# %%
data.tail(5)
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %% [markdown]
# TO  VIEW THE NO OF ROWS AND COLUMNS - SHAPE

# %%
data.shape
# Out:
# (7789, 11)

# %% [markdown]
# TO VIEW THE TOTAL NO OF RECORDS - SIZE

# %%
data.size
# Out:
# 85679

# %% [markdown]
# TO VIEW THE NAME OF TH COLUMN NAMES - COLUMNS

# %%
data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %% [markdown]
# TO VIEW THE DATA TYPE - DTYPE

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %% [markdown]
# TO VIEW DETAILS LIKE NO OF ROWS,COLUMNS,DATA TYPE,NULL AND NOT NULL VALUES - INFO()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# # TASK 1 : IF THERE ARE ANY DUPLICATES ,IF YES- REMOVE IT

# %%
# FIRST JUST T0 CHECK THE DATA
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
# GETTING A VIEW OF NO OF ROWS AND COLUMNS
data.shape
# Out:
# (7787, 11)

# %%
# TO KNOW THE DUPLICATE BUT THE VALUES WILL BE TRUE AND FALSE (BOLLEAN)
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Length: 7789, dtype: bool

# %%
# FROM DATA VARAIBLE WHICH ARE THE DATA THAT IS SHOWING DUPLICATES AS TRUE -
# PUT THE SQAURE BRACKET THAT INDICTAE THAT FROM DATA VARAIABLE WE WWANT ONLY DUPLICATES
data[data.duplicated()]       # BUT THIS REMOVALL WILL BE TEMPORARY
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
data.drop_duplicates()
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
# TO MAKE THE DUPLICATE REMOVAL PERMANENT
data.drop_duplicates( inplace=True )

# %% [markdown]
# # TASK 2 : IS THERE ANY NULL VALUES ,SHOW WITH THE USE OF HEAT MAP

# %% [markdown]
# ISNULL()

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
# TO SHOW THE NULL VALUES BUT VALUES WILL BE IN TRUE AND FALSE (BOLLEAN VALUE)
data.isnull()
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
# TO SHOW THE COUNT OF NULL VALUES 
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %% [markdown]
# SEABORN LIBRARY (HEAT MAP)

# %%
# Before importing one may need to install the package -“pip install seaborn” or “conda install seaborn”
# IMPRT THE LIBRARY
import seaborn as sbrn

# %%
# TO SHOW THE HEAT MAP 
sbrn.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# <!-- # Q.1 FOR HOUSE OF CARDS WHAAT IS THE SHOW ID AND NAME OF DIRECTOR -->

# %% [markdown]
# # Q.1. For 'House of Cards', what is the Show ld and Who is the Director of this show ?

# %% [markdown]
# METHOD 1 -ISIN()

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
# TO SHOW ALL RECORDS OF A PARTICULAR ITEM IN A COLUMN
data[data['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# METHOD 2-STR.CONTAINS()

# %%
# TO SHOW ALL RECORDS OF A PARTICULAR STRING IN ANY COLUMN
data[data['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# # Q.2. In which year highest number of the TV Shows & Movies were released ? Show with Bar Graph.

# %% [markdown]
# dtypes

# %%
data.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_N          datetime64[ns]
# dtype: object

# %% [markdown]
# to_datetime

# %%
# CREATE NEW COLUMN FOR DATE 
data['Date_N'] = pd.to_datetime(data['Release_Date'])

# %% [markdown]
# dt.year.value.counts()

# %%
# TO COUNT THE OCCURANCE OF YEAR IN THE DATE COLUMN
data['Date_N'].dt.year.value_counts()
# Out:
# Date_N
# 2019.0    2154
# 2020.0    2010
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %% [markdown]
# Bar graphs

# %%
#error 
data['Date_N'] = pd.to_datetime(data['Date_N'])
data['Date_N'].dt.year.value_counts().plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[99], line 2
#       1 data['Date_N'] = pd.to_datetime(data['Date_N'])
# ----> 2 data['Date_N'].dt.year.value_counts().plot(kind='bar')
#
# File ~\miniconda3\lib\site-packages\pandas\plotting\_core.py:975, in __call__(self, *args, **kwargs)
#     972 if int_y_arg and not data.columns.holds_integer():
#     973     y = data_cols[y]
# --> 975 label_kw = kwargs["label"] if "label" in kwargs else False
#     976 for kw in ["xerr", "yerr"]:
#     977     if kw in kwargs and (
#     978         isinstance(kwargs[kw], str) or is_integer(kwargs[kw])
#     979     ):
#
# File ~\miniconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
# ...

# %%
#error
data['Date_N'] = pd.to_datetime(data['Date_N'])
year_counts = data.groupby(data['Date_N'].dt.year).size()
year_counts.plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[100], line 3
#       1 data['Date_N'] = pd.to_datetime(data['Date_N'])
#       2 year_counts = data.groupby(data['Date_N'].dt.year).size()
# ----> 3 year_counts.plot(kind='bar')
#
# File ~\miniconda3\lib\site-packages\pandas\plotting\_core.py:975, in __call__(self, *args, **kwargs)
#     972 if int_y_arg and not data.columns.holds_integer():
#     973     y = data_cols[y]
# --> 975 label_kw = kwargs["label"] if "label" in kwargs else False
#     976 for kw in ["xerr", "yerr"]:
#     977     if kw in kwargs and (
#     978         isinstance(kwargs[kw], str) or is_integer(kwargs[kw])
#     979     ):
#
# File ~\miniconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
# ...

# %%
#error 
data['Date_N'] = pd.to_datetime(data['Date_N'])
year_counts = data.groupby(data['Date_N'].dt.year).size().reset_index(name='count')
year_counts.plot(x='Date_N', y='count', kind='bar')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[101], line 3
#       1 data['Date_N'] = pd.to_datetime(data['Date_N'])
#       2 year_counts = data.groupby(data['Date_N'].dt.year).size().reset_index(name='count')
# ----> 3 year_counts.plot(x='Date_N', y='count', kind='bar')
#
# File ~\miniconda3\lib\site-packages\pandas\plotting\_core.py:975, in __call__(self, *args, **kwargs)
#     972 if int_y_arg and not data.columns.holds_integer():
#     973     y = data_cols[y]
# --> 975 label_kw = kwargs["label"] if "label" in kwargs else False
#     976 for kw in ["xerr", "yerr"]:
#     977     if kw in kwargs and (
#     978         isinstance(kwargs[kw], str) or is_integer(kwargs[kw])
#     979     ):
#
# File ~\miniconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
# ...

# %%
import matplotlib.pyplot as plt

data['Date_N'] = pd.to_datetime(data['Date_N'])
year_counts = data.groupby(data['Date_N'].dt.year).size().reset_index(name='count')

plt.bar(year_counts['Date_N'], year_counts['count'])
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Number of records per year')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Q3.How many Movies & TV Shows are in the dataset ? Show with bar graph

# %% [markdown]
# groupby

# %%
# GROUPBY CATEGORY
data.groupby('Category')

# %%
# COUNT THE GROUPED COUNT
data.groupby('Category').Category.count()
# Out:
# Category
# Movie      5379
# TV Show    2410
# Name: Category, dtype: int64

# %%
import seaborn as sns

data['Category'] = data['Category'].astype('category')
sns.countplot(data=data, x='Category', palette=['red', 'blue'])
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %% [markdown]
# # Q. 4 SHOW ALL MOVIES THAT WERE RELEASED IN YEAR 2000

# %%
# CREATING NEW COLUMN 

data['Year'] = data['Date_N'].dt.year

# %%
# TO APPLY THE FILTER
data[ (data['Category'] == 'Movie') & (data['Year'] == 2015)]
# Out:
#      Show_Id Category                                              Title  \
# 128     s129    Movie                                            6 Years
# 247     s248    Movie                            A Very Murray Christmas
# 316     s317    Movie                                       Advantageous
# 535     s536    Movie                         Anjelah Johnson: Not Fancy
# 551     s552    Movie             Anthony Jeselnik: Thoughts and Prayers
# 648     s649    Movie          Aziz Ansari Live at Madison Square Garden
# 785     s786    Movie                                Beasts of No Nation
# 1013   s1014    Movie                                Bob's Broken Sleigh
# 1352   s1353    Movie                         Chris D'Elia: Incorrigible
# 1357   s1358    Movie                                  Chris Tucker Live
# 1394   s1395    Movie                                             Circle
# 1513   s1514    Movie              Cowspiracy: The Sustainability Secret
# ...

# %% [markdown]
# # Q.4 SHOW ONLY THE TITLES OF ALL TV SHOWS THAT WERE RELEASED IN INDIA ONLY

# %%
data.head()

# %%
# TO SHOW FILTER WITH SPECIFIC COLUMN (Title)
data[ (data['Category'] == 'TV Show') & (data['Country'] == 'India')] ['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# # Q.6 SHOW TOP 10 DIRECTORS ,WHO GAVE THE HIGHEST NUMBER OF TV SHOWS & MOVIES TO NETFLIX

# %% [markdown]
# value_counts()

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0   2020-08-14  TV-MA  4 Seasons
# 1   2016-12-23  TV-MA     93 min
# 2   2018-12-20      R     78 min
# 3   2017-11-16  PG-13     80 min
# 4   2020-01-01  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
data['Director'].value_counts().head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Robert Rodriguez           8
# Name: count, dtype: int64

# %% [markdown]
# # Q.7 SHOW ALL THE RECORDS,WHERE 'Category is Movie and Type is Comedies' or 'Country is United Kingdom'

# %%
# AND CONDITION
data[(data['Category'] == 'Movie') & (data['Type']=='Comedies')]
# Out:
#      Show_Id Category                        Title                Director  \
# 33       s34    Movie                 #realityhigh        Fernando Lebrija
# 72       s73    Movie                     17 Again             Burr Steers
# 84       s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175    Movie  A Futile and Stupid Gesture              David Wain
# ...      ...      ...                          ...                     ...
# 7341   s7340    Movie         Undercover Brother 2            Leslie Small
# 7590   s7589    Movie            Where's the Money         Scott Zabielski
# 7623   s7622    Movie                    Wild Oats            Andy Tennant
# 7634   s7633    Movie                 Wine Country             Amy Poehler
# 7664   s7663    Movie                      Work It           Laura Terruso
#
#                                                    Cast  \
# ...

# %%
# OR CONDITION 
data[(data['Category'] == 'Movie') & (data['Type']=='Comedies') | (data['Country']=='United Kingdom')]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [markdown]
# ## Q.8 HOW MANY MOVIES /SHOWS,TOM CRUISE WAS CAST ?

# %%
# data.cast or data['cast']better when space and under
#is there  but are  same 
# WE WONT GET VALUE HERE BECOUSE THERE IS MULTIPLE VALUE IN CAST
data[data['Cast']== 'Tom Cruise']
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %%
# THERE IS AN NULL OR NA VALUES THATS WHY WE WILL GET ERROR
data[data['Cast'].str.contains('Tom Cruise')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[137], line 1
# ----> 1 data[data['Cast'].str.contains('Tom Cruise')]
#
# File ~\miniconda3\lib\site-packages\pandas\core\frame.py:3751, in __getitem__(self, key)
#    3747 def _iter_column_arrays(self) -> Iterator[ArrayLike]:
#    3748     """
#    3749     Iterate over the arrays of all columns in order.
#    3750     This returns the values as stored in the Block (ndarray or ExtensionArray).
# -> 3751
#    3752     Warning! The returned array is a view but doesn't handle Copy-on-Write,
#    3753     so this should be used with caution (for read-only purposes).
#    3754     """
#    3755     for i in range(len(self.columns)):
#    3756         yield self._get_column_array(i)
#
# File ~\miniconda3\lib\site-packages\pandas\core\common.py:134, in is_bool_indexer(key)
#     130 if not lib.is_bool_array(key_array):
# ...

# %% [markdown]
# CREATING NEW DATA-FRAME

# %%
# USING DROPNA TOCREATE A DATAFRAME WITHOUT NA 
data_new=data.dropna()

# %%
data_new.head()
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#   Release_Date Rating  Duration  \
# 1   2016-12-23  TV-MA    93 min
# 2   2018-12-20      R    78 min
# 3   2017-11-16  PG-13    80 min
# 4   2020-01-01  PG-13   123 min
# 5   2017-07-01  TV-MA  1 Season
#
#                                                 Type  \
# ...

# %%
# NOW APPLYNG THE SAME CODE IN THIS 
data_new[data_new['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      Release_Date Rating Duration                        Type  \
# 3860   2020-01-01      R  189 min  Dramas, Independent Movies
# 5071   2019-07-01      R  134 min      Classic Movies, Dramas
#
#                                             Description     Date_N    Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %% [markdown]
# ## Q.9. What are the different Ratings defined by Netflix ?

# %% [markdown]
# NUNIQUE

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0   2020-08-14  TV-MA  4 Seasons
# 1   2016-12-23  TV-MA     93 min
# 2   2018-12-20      R     78 min
# 3   2017-11-16  PG-13     80 min
# 4   2020-01-01  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
data['Rating'].nunique()
# Out:
# 14

# %% [markdown]
# UNIQUE

# %%
data['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# # # Q.9.How many Movies got the TV-14' rating, in Canada ?

# %%
data[(data['Category']=='Movie') & (data['Rating']=='TV-14')].shape
# Out:
# (1272, 13)

# %%
data[(data['Category']=='Movie') & (data['Rating']=='TV-14') & (data['Country']=='Canada')].shape
# Out:
# (11, 13)

# %% [markdown]
#  ## Q.10 How many TV Show got the "R" rating, after year 2018  ?

# %%
data[(data['Category']== 'TV Show') & (data['Rating']=='R') & (data['Year'] >2018)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country Release_Date  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN   2019-04-25
#
#      Rating  Duration      Type  \
# 6437      R  1 Season  TV Shows
#
#                                             Description     Date_N    Year
# 6437  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %% [markdown]
# ## Q.11 WHAT IS THE MAXIMUM DURATION OF A MOVIE/SHOW ON NETFLIX ?

# %%
data.Duration.unique() # to show all the values
data.Duration.unique # will list all the distinct value
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %% [markdown]
#  str.split

# %%
# to convert into numeric format before that split the number and string
data[['Minutes','Units']]=data['Duration'].str.split(' ' ,expand= True )

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   Minutes    Units
# 0       4  Seasons
# 1      93      min

# %%
# FINDING MAXIMUM VALUE 

data['Minutes'].max()
# Out:
# '99'

# %%
# FINDING MININUM VALUE 

data['Minutes'].min()
# Out:
# '1'

# %% [markdown]
# # Q. 11. Which individual country has the Highest No. of TV Shows ?

# %%
data.head(3
        )
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico   2016-12-23
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore   2018-12-20
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
# 2      R     78 min                Horror Movies, International Movies
#
#                                          Description     Date_N    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# ...

# %%
# create new dataframe 
data_tvshow  = data[data['Category']=='TV Show']

# %%
data_tvshow.head(2)
# Out:
#   Show_Id Category Title     Director  \
# 0      s1  TV Show    3%          NaN
# 5      s6  TV Show    46  Serdar Akar
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey   2017-07-01
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 5  TV-MA   1 Season    International TV Shows, TV Dramas, TV Mysteries
#
#                                          Description     Date_N    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 5  A genetics professor experiments with a treatm... 2017-07-01  2017.0
#
#   Minutes    Units
# 0       4  Seasons
# 5       1   Season

# %%
data_tvshow.Country.value_counts()
# Out:
# Country
# United States                                                705
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: count, Length: 183, dtype: int64

# %%
data_tvshow.Country.value_counts().head(1)
# Out:
# Country
# United States    705
# Name: count, dtype: int64

# %% [markdown]
# ## Q.13 HOW WE CAN SORT THE DATASET BY YEAR ?

# %%
data.sort_values(by = 'Year')
# Out:
#      Show_Id Category                         Title              Director  \
# 7115   s7114    Movie          To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show               Dinner for Five                   NaN
# 5766   s5766    Movie                      Splatter             Joe Dante
# 3248   s3249    Movie       Just Another Love Story          Ole Bornedal
# 3840   s3841    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 3374   s3375  TV Show                      Kikoriki                   NaN
# 3492   s3493  TV Show           La Familia P. Luche                   NaN
# 3946   s3947  TV Show                         Maron                   NaN
# 5138   s5138  TV Show                  Red vs. Blue                   NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    Cast        Country  \
# ...

# %%
data.sort_values(by = 'Year',ascending=False)
# Out:
#      Show_Id Category                         Title  \
# 7353   s7352    Movie                       Unknown
# 2013   s2014    Movie              Enter the Dragon
# 2349   s2350    Movie                     Gangaajal
# 1497   s1498    Movie                Cool Hand Luke
# 1194   s1195    Movie             Can't Hardly Wait
# ...      ...      ...                           ...
# 3374   s3375  TV Show                      Kikoriki
# 3492   s3493  TV Show           La Familia P. Luche
# 3946   s3947  TV Show                         Maron
# 5138   s5138  TV Show                  Red vs. Blue
# 6066   s6066  TV Show  The Adventures of Figaro Pho
#
#                           Director  \
# 7353            Jaume Collet-Serra
# 2013                 Robert Clouse
# 2349                   Prakash Jha
# 1497              Stuart Rosenberg
# 1194  Harry Elfont, Deborah Kaplan
# ...                            ...
# 3374                           NaN
# 3492                           NaN
# ...

# %% [markdown]
# # Q.13 FIND ALL THE INTENSES WHERE Category is Movie and Type is Dramas or Category is TV Show and Type is Kids TV ?

# %%
data[(data['Category']=='Movie') & (data['Type']=='Dramas') | (data['Category']=='TV Shows') & (data['Type']=='Kidz TV')]
# Out:
#      Show_Id Category                       Title           Director  \
# 4         s5    Movie                          21     Robert Luketic
# 7         s8    Movie                         187     Kevin Reynolds
# 170     s171    Movie                A Family Man      Mark Williams
# 232     s233    Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296    Movie          Across Grace Alley      Ralph Macchio
# ...      ...      ...                         ...                ...
# 7417   s7416    Movie                      Victor  Brandon Dickerson
# 7422   s7421    Movie                     Villain   Philip Barantini
# 7449   s7448    Movie                         VS.           Ed Lilly
# 7465   s7464    Movie                   Wakefield      Robin Swicord
# 7480   s7479    Movie                   War Horse   Steven Spielberg
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...
